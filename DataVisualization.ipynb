# %% [markdown]
# Import the data CSV, group by empty cell count

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("sudoku_boards_sorted.csv")
groups = df.groupby("zero_count")
counts = [0] * 81

# %%
for zero_count, gropu in groups:
    counts[zero_count] += 1
